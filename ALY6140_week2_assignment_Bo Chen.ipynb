# %%
#Student name: Bo Chen
#NUID:002923800
#Date: 11/11/2023

# %%
#To establish a connection between the Google Drive account and Google Colab notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Create a function to read the csv file
def import_csv(file_path):
    """
    This function reads a CSV file and returns its contents as a DataFrame.

    :param file_path: str, the path to the csv file
    :return: DataFrame, the contents of the csv file
    """
    df = pd.read_csv(file_path)
    return df
if __name__ == '__main__':
    csv_path = '/content/drive/MyDrive/Colab Notebooks/ALY6140 assignment folder/Week2/Neural_data.csv'

    #Call the functions and store the results
    csv_data = import_csv(csv_path)

# %%
#check the head of the csv file
csv_data.head()
# Out:
#    Intensity_MassDisplacement_PI  Intensity_MaxIntensityEdge_DAPI  \
# 0                       0.071353                         0.056657
# 1                       0.127836                         0.054536
# 2                       0.105791                         0.068132
# 3                       0.144962                         0.043870
# 4                       0.148326                         0.055924
#
#    Intensity_MaxIntensityEdge_PI  Intensity_MaxIntensity_DAPI  \
# 0                       0.039338                     0.148211
# 1                       0.038636                     0.157321
# 2                       0.034424                     0.120699
# 3                       0.036103                     0.133516
# 4                       0.038834                     0.142733
#
#    Intensity_MaxIntensity_PI  Intensity_MeanIntensityEdge_DAPI  \
# 0                   0.042130                          0.040214
# 1                   0.040787                          0.039137
# ...

# %%
#Create a function to read the txt file
def import_text(file_path):
    """
    This function reads a text file and returns its contents as a list of lines.

    :param file_path: str, the path to the text file
    :return: list, the contents of the text file
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()
    return lines
if __name__ == '__main__':
    text_path = '/content/drive/MyDrive/Colab Notebooks/ALY6140 assignment folder/Week2/network_data.txt'

    #Call the functions and store the results
    text_data = import_text(text_path)

# %%
#check the first line in the text file
print(text_data[0])
# Out:
# id_visitor|id_session|dim_session_number|dim_user_agent|dim_device_app_combo|ds|ts_min|ts_max|did_search|sent_message|sent_booking_request|next_id_session|next_dim_session_number|next_dim_user_agent|next_dim_device_app_combo|next_ds|next_ts_min|next_ts_max|next_did_search|next_sent_message|next_sent_booking_request

# %%
#Create a function to read the excel file,exlude the blank rows and coloumns
def import_excel(file_path, sheet_name):
    """
    This function reads an Excel file and returns a specified sheet's contents as a DataFrame.

    :param file_path: str, the path to the excel file
    :param sheet_name: str, the name of the sheet to be imported
    :return: DataFrame, the contents of the specified sheet
    """
    df = pd.read_excel(file_path, sheet_name=sheet_name,header=24,usecols=lambda x: 'Unnamed' not in x,)
    return df
if __name__ == '__main__':
    excel_path = '/content/drive/MyDrive/Colab Notebooks/ALY6140 assignment folder/Week2/Excel_report.xlsx'

    #Call the functions and store the results
    excel_data = import_excel(excel_path,'financials')

# %%
#check the head of the csv file
excel_data.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales    Sales     COGS   Profit  \
# 0                    3          20      32370.0  32370.0  16185.0  16185.0
# 1                    3          20      26420.0  26420.0  13210.0  13210.0
# 2                    3          15      32670.0  32670.0  21780.0  10890.0
# 3                    3          15      13320.0  13320.0   8880.0   4440.0
# 4                    3          15      37050.0  37050.0  24700.0  12350.0
#
#         Date  Month Number Month Name  Year
# 0 2014-01-01             1    January  2014
# 1 2014-01-01             1    January  2014
# ...

# %%
#Create a function to read the jason file
def import_json(file_path):
    """
    This function reads a JSON file and returns its contents as a Python dictionary.

    :param file_path: str, the path to the json file
    :return: dict, the contents of the json file
    """
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data
if __name__ == '__main__':
    json_path = '/content/drive/MyDrive/Colab Notebooks/ALY6140 assignment folder/Week2/nested_data.json'

    #Call the functions and store the results
    json_data = import_json(json_path)

# %%
#check the first 2 rows of json data
json_data[0:2]
# Out:
# [{'name': 'Aachen',
#   'id': '1',
#   'nametype': 'Valid',
#   'recclass': 'L5',
#   'mass': '21',
#   'fall': 'Fell',
#   'year': '1880-01-01T00:00:00.000',
#   'reclat': '50.775000',
#   'reclong': '6.083330',
#   'geolocation': {'type': 'Point', 'coordinates': [6.08333, 50.775]}},
#  {'name': 'Aarhus',
#   'id': '2',
#   'nametype': 'Valid',
#   'recclass': 'H6',
#   'mass': '720',
#   'fall': 'Fell',
#   'year': '1951-01-01T00:00:00.000',
#   'reclat': '56.183330',
#   'reclong': '10.233330',
#   'geolocation': {'type': 'Point', 'coordinates': [10.23333, 56.18333]}}]

# %%
#check the type of json data
type(json_data)
# Out:
# list
